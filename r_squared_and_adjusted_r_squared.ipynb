# %%
#Import libraries
import pandas as pd
import numpy as np

# %%
#import dataset
mt = pd.read_csv('mtcars.csv')
mt.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
#import statsmodel.api to calculate r- square dnd adjacent r-squared
import statsmodels.api as sm

#take only one features at a time : mpg
x_opt = mt.iloc[:, 1:2]
y = mt.hp

regressor_OLS = sm.OLS(endog = y, exog = x_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     hp   R-squared (uncentered):                   0.608
# Model:                            OLS   Adj. R-squared (uncentered):              0.595
# Method:                 Least Squares   F-statistic:                              47.98
# Date:                Tue, 20 Dec 2022   Prob (F-statistic):                    9.06e-08
# Time:                        18:30:54   Log-Likelihood:                         -193.14
# No. Observations:                  32   AIC:                                      388.3
# Df Residuals:                      31   BIC:                                      389.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# mpg            6.0078      0.867      6.927      0.000       4.239       7.777
# ==============================================================================
# Omnibus:                        1.128   Durbin-Watson:                   1.301
# Prob(Omnibus):                  0.569   Jarque-Bera (JB):                0.980
# Skew:                           0.209   Prob(JB):                        0.613
# Kurtosis:                       2.251   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#import statsmodel.api to calculate r- square dnd adjacent r-squared
import statsmodels.api as sm

#take only one features at a time : mpg
x_opt = mt.iloc[:, 1:3]
y = mt.hp

regressor_OLS = sm.OLS(endog = y, exog = x_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     hp   R-squared (uncentered):                   0.949
# Model:                            OLS   Adj. R-squared (uncentered):              0.945
# Method:                 Least Squares   F-statistic:                              276.4
# Date:                Tue, 20 Dec 2022   Prob (F-statistic):                    4.72e-20
# Time:                        18:31:23   Log-Likelihood:                         -160.64
# No. Observations:                  32   AIC:                                      325.3
# Df Residuals:                      30   BIC:                                      328.2
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# mpg           -1.4653      0.619     -2.368      0.025      -2.729      -0.202
# cyl           28.4112      2.015     14.098      0.000      24.295      32.527
# ==============================================================================
# Omnibus:                       15.651   Durbin-Watson:                   1.320
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.876
# Skew:                           1.316   Prob(JB):                     7.97e-05
# Kurtosis:                       5.690   Cond. No.                         6.76
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#import statsmodel.api to calculate r- square dnd adjacent r-squared
import statsmodels.api as sm

#take only one features at a time : mpg
x_opt = mt.iloc[:, 1:4]
y = mt.hp

regressor_OLS = sm.OLS(endog = y, exog = x_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     hp   R-squared (uncentered):                   0.949
# Model:                            OLS   Adj. R-squared (uncentered):              0.944
# Method:                 Least Squares   F-statistic:                              180.3
# Date:                Tue, 20 Dec 2022   Prob (F-statistic):                    7.58e-19
# Time:                        18:31:36   Log-Likelihood:                         -160.45
# No. Observations:                  32   AIC:                                      326.9
# Df Residuals:                      29   BIC:                                      331.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# mpg           -1.1282      0.856     -1.319      0.198      -2.878       0.622
# cyl           24.3860      7.259      3.359      0.002       9.539      39.233
# disp           0.0787      0.136      0.578      0.568      -0.200       0.357
# ==============================================================================
# Omnibus:                       18.852   Durbin-Watson:                   1.314
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.380
# Skew:                           1.489   Prob(JB):                     1.87e-06
# Kurtosis:                       6.304   Cond. No.                         282.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#import statsmodel.api to calculate r- square dnd adjacent r-squared
import statsmodels.api as sm

#take only one features at a time : mpg
x_opt = mt.iloc[:, 1:5]
y = mt.hp

regressor_OLS = sm.OLS(endog = y, exog = x_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     hp   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          3.976e+31
# Date:                Tue, 20 Dec 2022   Prob (F-statistic):                        0.00
# Time:                        18:31:56   Log-Likelihood:                          924.93
# No. Observations:                  32   AIC:                                     -1842.
# Df Residuals:                      28   BIC:                                     -1836.
# Df Model:                           4
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# mpg        -2.665e-15   1.67e-15     -1.598      0.121   -6.08e-15    7.51e-16
# cyl         7.105e-15   1.62e-14      0.439      0.664   -2.61e-14    4.03e-14
# disp       -5.551e-17   2.59e-16     -0.214      0.832   -5.87e-16    4.76e-16
# hp             1.0000   3.51e-16   2.85e+15      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                        1.156   Durbin-Watson:                   0.868
# Prob(Omnibus):                  0.561   Jarque-Bera (JB):                1.107
# Skew:                          -0.319   Prob(JB):                        0.575
# Kurtosis:                       2.349   Cond. No.                         387.
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#import statsmodel.api to calculate r- square dnd adjacent r-squared
import statsmodels.api as sm

#take only one features at a time : mpg
x_opt = mt.iloc[:, 1:10]
y = mt.hp

regressor_OLS = sm.OLS(endog = y, exog = x_opt).fit()
regressor_OLS.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                     hp   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          7.435e+31
# Date:                Tue, 20 Dec 2022   Prob (F-statistic):                        0.00
# Time:                        18:32:27   Log-Likelihood:                          951.07
# No. Observations:                  32   AIC:                                     -1884.
# Df Residuals:                      23   BIC:                                     -1871.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# mpg        -4.441e-16   2.84e-15     -0.156      0.877   -6.32e-15    5.43e-15
# cyl         2.487e-14   1.01e-14      2.460      0.022    3.96e-15    4.58e-14
# disp        -1.11e-16   1.72e-16     -0.645      0.525   -4.67e-16    2.45e-16
# hp             1.0000   2.27e-16   4.41e+15      0.000       1.000       1.000
# drat        7.105e-15   1.83e-14      0.389      0.701   -3.07e-14    4.49e-14
# wt                  0   2.12e-14          0      1.000   -4.38e-14    4.38e-14
# qsec       -8.882e-15   6.26e-15     -1.419      0.169   -2.18e-14    4.07e-15
# vs          4.974e-14   2.78e-14      1.788      0.087    -7.8e-15    1.07e-13
# am         -1.421e-14   2.56e-14     -0.556      0.584   -6.71e-14    3.87e-14
# ==============================================================================
# Omnibus:                        0.857   Durbin-Watson:                   1.542
# Prob(Omnibus):                  0.652   Jarque-Bera (JB):                0.764
# Skew:                          -0.002   Prob(JB):                        0.682
# Kurtosis:                       2.243   Cond. No.                     1.52e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.52e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
